# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sbn

# %%
df=pd.read_excel("merc.xlsx")

# %%
df
# Out:
#        year  price transmission  mileage  tax   mpg  engineSize
# 0      2005   5200    Automatic    63000  325  32.1         1.8
# 1      2017  34948    Automatic    27000   20  61.4         2.1
# 2      2016  49948    Automatic     6200  555  28.0         5.5
# 3      2016  61948    Automatic    16000  325  30.4         4.0
# 4      2016  73948    Automatic     4000  325  30.1         4.0
# ...     ...    ...          ...      ...  ...   ...         ...
# 13114  2020  35999    Automatic      500  145  55.4         2.0
# 13115  2020  24699    Automatic     2500  145  55.4         2.0
# 13116  2019  30999    Automatic    11612  145  41.5         2.1
# 13117  2019  37990    Automatic     2426  145  45.6         2.0
# 13118  2019  54999    Automatic     2075  145  52.3         2.9
#
# [13119 rows x 7 columns]

# %%
df.head()
# Out:
#    year  price transmission  mileage  tax   mpg  engineSize
# 0  2005   5200    Automatic    63000  325  32.1         1.8
# 1  2017  34948    Automatic    27000   20  61.4         2.1
# 2  2016  49948    Automatic     6200  555  28.0         5.5
# 3  2016  61948    Automatic    16000  325  30.4         4.0
# 4  2016  73948    Automatic     4000  325  30.1         4.0

# %%
df.describe()
# Out:
#                year          price        mileage           tax           mpg  \
# count  13119.000000   13119.000000   13119.000000  13119.000000  13119.000000
# mean    2017.296288   24698.596920   21949.559037    129.972178     55.155843
# std        2.224709   11842.675542   21176.512267     65.260286     15.220082
# min     1970.000000     650.000000       1.000000      0.000000      1.100000
# 25%     2016.000000   17450.000000    6097.500000    125.000000     45.600000
# 50%     2018.000000   22480.000000   15189.000000    145.000000     56.500000
# 75%     2019.000000   28980.000000   31779.500000    145.000000     64.200000
# max     2020.000000  159999.000000  259000.000000    580.000000    217.300000
#
#          engineSize
# count  13119.000000
# mean       2.071530
# std        0.572426
# min        0.000000
# 25%        1.800000
# 50%        2.000000
# 75%        2.100000
# max        6.200000

# %%
df.isnull
# Out:
# <bound method DataFrame.isnull of        year  price transmission  mileage  tax   mpg  engineSize
# 0      2005   5200    Automatic    63000  325  32.1         1.8
# 1      2017  34948    Automatic    27000   20  61.4         2.1
# 2      2016  49948    Automatic     6200  555  28.0         5.5
# 3      2016  61948    Automatic    16000  325  30.4         4.0
# 4      2016  73948    Automatic     4000  325  30.1         4.0
# ...     ...    ...          ...      ...  ...   ...         ...
# 13114  2020  35999    Automatic      500  145  55.4         2.0
# 13115  2020  24699    Automatic     2500  145  55.4         2.0
# 13116  2019  30999    Automatic    11612  145  41.5         2.1
# 13117  2019  37990    Automatic     2426  145  45.6         2.0
# 13118  2019  54999    Automatic     2075  145  52.3         2.9
#
# [13119 rows x 7 columns]>

# %%
df.isnull().sum()
# Out:
# year            0
# price           0
# transmission    0
# mileage         0
# tax             0
# mpg             0
# engineSize      0
# dtype: int64

# %%
sbn.displot(df["price"])

# %%
df.dtypes
# Out:
# year              int64
# price             int64
# transmission     object
# mileage           int64
# tax               int64
# mpg             float64
# engineSize      float64
# dtype: object

# %%
df=pd.get_dummies(df,columns=['transmission'],drop_first=True)

# %%
df.corr()["price"].sort_values
# Out:
# <bound method Series.sort_values of year                      0.520712
# price                     1.000000
# mileage                  -0.537214
# tax                       0.268717
# mpg                      -0.438445
# engineSize                0.516126
# transmission_Manual      -0.274886
# transmission_Other       -0.009229
# transmission_Semi-Auto    0.190593
# Name: price, dtype: float64>

# %%
df.corr()
# Out:
#                             year     price   mileage       tax       mpg  \
# year                    1.000000  0.520712 -0.738027  0.012480 -0.094626
# price                   0.520712  1.000000 -0.537214  0.268717 -0.438445
# mileage                -0.738027 -0.537214  1.000000 -0.160223  0.202850
# tax                     0.012480  0.268717 -0.160223  1.000000 -0.513742
# mpg                    -0.094626 -0.438445  0.202850 -0.513742  1.000000
# engineSize             -0.142147  0.516126  0.063652  0.338341 -0.339862
# transmission_Manual    -0.135518 -0.274886  0.172088 -0.211461  0.102470
# transmission_Other     -0.009971 -0.009229  0.007579  0.001424  0.001091
# transmission_Semi-Auto  0.245092  0.190593 -0.246734  0.048944 -0.043480
#
#                         engineSize  transmission_Manual  transmission_Other  \
# year                     -0.142147            -0.135518           -0.009971
# price                     0.516126            -0.274886           -0.009229
# mileage                   0.063652             0.172088            0.007579
# tax                       0.338341            -0.211461            0.001424
# mpg                      -0.339862             0.102470            0.001091
# engineSize                1.000000            -0.215249           -0.022037
# transmission_Manual      -0.215249             1.000000           -0.004343
# transmission_Other       -0.022037            -0.004343            1.000000
# transmission_Semi-Auto    0.019372            -0.367510           -0.012904
#
#                         transmission_Semi-Auto
# year                                  0.245092
# price                                 0.190593
# mileage                              -0.246734
# tax                                   0.048944
# mpg                                  -0.043480
# engineSize                            0.019372
# transmission_Manual                  -0.367510
# transmission_Other                   -0.012904
# transmission_Semi-Auto                1.000000

# %%
sbn.scatterplot(x="mileage",y="price",data=df)
# Out:
# <Axes: xlabel='mileage', ylabel='price'>

# %%
df.sort_values("price",ascending=False).head(20)
# Out:
#        year   price  mileage  tax   mpg  engineSize  transmission_Manual  \
# 6199   2020  159999     1350  145  21.4         4.0                False
# 10044  2020  154998     3000  150  21.4         4.0                False
# 5      2011  149948     3000  570  21.4         6.2                False
# 8737   2019  140319      785  150  22.1         4.0                False
# 6386   2018  139995    13046  145  21.4         4.0                False
# 8      2019  139948    12000  145  21.4         4.0                False
# 9133   2019  139559     1000  145  22.1         4.0                False
# 8821   2020  138439     1000  145  22.1         4.0                False
# 5902   2018  135771    19000  145  21.4         4.0                False
# 7864   2018  135124    18234  150  21.4         4.0                False
# 8673   2019  134219     1000  145  24.8         4.0                False
# 6210   2019  129990     1000  145  24.8         4.0                False
# 4759   2019  126000      250  145  24.6         4.0                False
# 2647   2019  125796      637  145  24.8         4.0                False
# 6223   2019  124999     1500  145  31.7         4.0                False
# 4094   2019  124366      880  145  24.8         4.0                False
# 2629   2019  123846     2951  145  22.1         4.0                False
# 7134   2019  115359     1000  145  30.1         4.0                False
# 9159   2019  114199      891  145  22.6         4.0                False
# 1980   2019  109995     4688  150  31.7         4.0                False
#
#        transmission_Other  transmission_Semi-Auto
# 6199                False                    True
# 10044               False                   False
# 5                   False                   False
# 8737                False                    True
# 6386                False                    True
# 8                   False                   False
# 9133                False                    True
# 8821                False                    True
# 5902                False                    True
# 7864                False                    True
# 8673                False                    True
# 6210                False                   False
# 4759                False                   False
# 2647                False                   False
# 6223                False                   False
# 4094                False                    True
# 2629                False                    True
# 7134                False                    True
# 9159                False                    True
# 1980                False                    True

# %%
len(df)
# Out:
# 13119

# %%
len(df)*0.01
# Out:
# 131.19

# %%
df=df.sort_values("price",ascending=False).iloc[131:]

# %%
len(df)
# Out:
# 12988

# %%
df.describe()
# Out:
#                year         price        mileage           tax           mpg  \
# count  12988.000000  12988.000000   12988.000000  12988.000000  12988.000000
# mean    2017.281876  24074.926933   22132.741146    129.689714     55.437142
# std        2.228515   9866.224575   21196.776401     65.183076     15.025999
# min     1970.000000    650.000000       1.000000      0.000000      1.100000
# 25%     2016.000000  17357.500000    6322.000000    125.000000     45.600000
# 50%     2018.000000  22299.000000   15369.500000    145.000000     56.500000
# 75%     2019.000000  28706.000000   31982.250000    145.000000     64.200000
# max     2020.000000  65990.000000  259000.000000    580.000000    217.300000
#
#          engineSize
# count  12988.000000
# mean       2.050901
# std        0.532596
# min        0.000000
# 25%        1.675000
# 50%        2.000000
# 75%        2.100000
# max        6.200000

# %%
sbn.distplot(df["price"])
# Out:
# C:\Users\serif\AppData\Local\Temp\ipykernel_2428\1473216513.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sbn.distplot(df["price"])
# <Axes: xlabel='price', ylabel='Density'>

# %%
df.groupby("year").mean()["price"]
# Out:
# year
# 1970    24999.000000
# 1997     9995.000000
# 1998     8605.000000
# 1999     5995.000000
# 2000     5743.333333
# 2001     4957.900000
# 2002     5820.444444
# 2003     4878.000000
# 2004     4727.615385
# 2005     4426.111111
# 2006     4036.875000
# 2007     5136.045455
# 2008     6967.437500
# 2009     6166.764706
# 2010     8308.473684
# 2011     8913.459459
# 2012    10845.140351
# 2013    11939.842466
# 2014    14042.936864
# 2015    16647.822222
# 2016    19223.558943
# 2017    21356.280421
# 2018    24800.844506
# 2019    30289.524832
# 2020    34234.794872
# Name: price, dtype: float64

# %%
df[df.year!=1970].groupby("year").mean()["price"]
# Out:
# year
# 1997     9995.000000
# 1998     8605.000000
# 1999     5995.000000
# 2000     5743.333333
# 2001     4957.900000
# 2002     5820.444444
# 2003     4878.000000
# 2004     4727.615385
# 2005     4426.111111
# 2006     4036.875000
# 2007     5136.045455
# 2008     6967.437500
# 2009     6166.764706
# 2010     8308.473684
# 2011     8913.459459
# 2012    10845.140351
# 2013    11939.842466
# 2014    14042.936864
# 2015    16647.822222
# 2016    19223.558943
# 2017    21356.280421
# 2018    24800.844506
# 2019    30289.524832
# 2020    34234.794872
# Name: price, dtype: float64

# %%
df
# Out:
#        year  price  mileage  tax   mpg  engineSize  transmission_Manual  \
# 6177   2019  65990     5076  150  30.4         3.0                False
# 5779   2020  65990      999  145  28.0         4.0                False
# 3191   2020  65980     3999  145  28.0         4.0                False
# 4727   2019  65000     3398  145  27.2         4.0                False
# 8814   2019  64999      119  145  40.9         3.0                False
# ...     ...    ...      ...  ...   ...         ...                  ...
# 11549  2002   1495    13800  305  39.8         2.7                False
# 12594  2004   1495   119000  300  34.5         1.8                 True
# 11765  2000   1490    87000  265  27.2         3.2                False
# 12008  2010   1350   116126  145  54.3         2.0                 True
# 11816  2003    650   109090  235  40.0         1.4                 True
#
#        transmission_Other  transmission_Semi-Auto
# 6177                False                    True
# 5779                False                    True
# 3191                False                    True
# 4727                False                    True
# 8814                False                    True
# ...                   ...                     ...
# 11549               False                   False
# 12594               False                   False
# 11765               False                   False
# 12008               False                   False
# 11816               False                   False
#
# [12988 rows x 9 columns]

# %%
df=df[df.year!=1970]

# %%
df.groupby("year").mean()["price"]
# Out:
# year
# 1997     9995.000000
# 1998     8605.000000
# 1999     5995.000000
# 2000     5743.333333
# 2001     4957.900000
# 2002     5820.444444
# 2003     4878.000000
# 2004     4727.615385
# 2005     4426.111111
# 2006     4036.875000
# 2007     5136.045455
# 2008     6967.437500
# 2009     6166.764706
# 2010     8308.473684
# 2011     8913.459459
# 2012    10845.140351
# 2013    11939.842466
# 2014    14042.936864
# 2015    16647.822222
# 2016    19223.558943
# 2017    21356.280421
# 2018    24800.844506
# 2019    30289.524832
# 2020    34234.794872
# Name: price, dtype: float64

# %%
df[df.year!=1970].groupby("year").mean()["price"]
# Out:
# year
# 1997     9995.000000
# 1998     8605.000000
# 1999     5995.000000
# 2000     5743.333333
# 2001     4957.900000
# 2002     5820.444444
# 2003     4878.000000
# 2004     4727.615385
# 2005     4426.111111
# 2006     4036.875000
# 2007     5136.045455
# 2008     6967.437500
# 2009     6166.764706
# 2010     8308.473684
# 2011     8913.459459
# 2012    10845.140351
# 2013    11939.842466
# 2014    14042.936864
# 2015    16647.822222
# 2016    19223.558943
# 2017    21356.280421
# 2018    24800.844506
# 2019    30289.524832
# 2020    34234.794872
# Name: price, dtype: float64

# %%
df.groupby("year").mean()["price"]
# Out:
# year
# 1997     9995.000000
# 1998     8605.000000
# 1999     5995.000000
# 2000     5743.333333
# 2001     4957.900000
# 2002     5820.444444
# 2003     4878.000000
# 2004     4727.615385
# 2005     4426.111111
# 2006     4036.875000
# 2007     5136.045455
# 2008     6967.437500
# 2009     6166.764706
# 2010     8308.473684
# 2011     8913.459459
# 2012    10845.140351
# 2013    11939.842466
# 2014    14042.936864
# 2015    16647.822222
# 2016    19223.558943
# 2017    21356.280421
# 2018    24800.844506
# 2019    30289.524832
# 2020    34234.794872
# Name: price, dtype: float64

# %%
df.head()
# Out:
#       year  price  mileage  tax   mpg  engineSize  transmission_Manual  \
# 6177  2019  65990     5076  150  30.4         3.0                False
# 5779  2020  65990      999  145  28.0         4.0                False
# 3191  2020  65980     3999  145  28.0         4.0                False
# 4727  2019  65000     3398  145  27.2         4.0                False
# 8814  2019  64999      119  145  40.9         3.0                False
#
#       transmission_Other  transmission_Semi-Auto
# 6177               False                    True
# 5779               False                    True
# 3191               False                    True
# 4727               False                    True
# 8814               False                    True

# %%
y=df["price"].values
x=df.drop("price",axis=1).values

# %%
y
# Out:
# array([65990, 65990, 65980, ...,  1490,  1350,   650], dtype=int64)

# %%
x
# Out:
# array([[2019, 5076, 150, ..., False, False, True],
#        [2020, 999, 145, ..., False, False, True],
#        [2020, 3999, 145, ..., False, False, True],
#        ...,
#        [2000, 87000, 265, ..., False, False, False],
#        [2010, 116126, 145, ..., True, False, False],
#        [2003, 109090, 235, ..., True, False, False]], dtype=object)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=10)

# %%
len(x_train)
# Out:
# 9090

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler=MinMaxScaler()

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
x_train.shape
# Out:
# (9090, 8)

# %%
model=Sequential()

# %%
model.add(Dense(12,activation="relu"))
model.add(Dense(12,activation="relu"))
model.add(Dense(12,activation="relu"))
model.add(Dense(12,activation="relu"))
model.add(Dense(1))

# %%
model.compile(optimizer="adam",loss="mse")

# %%
model.fit(x=x_train,y=y_train,epochs=300)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 model.fit(x=x_train,y=y_train,epochs=300)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\framework\constant_op.py:103, in convert_to_eager_tensor(value, ctx, dtype)
#     101     dtype = dtypes.as_dtype(dtype).as_datatype_enum
#     102 ctx.ensure_initialized()
# --> 103 return ops.EagerTensor(value, ctx.device_name, dtype)
#
# ValueError: Failed to convert a NumPy array to a Tensor (Unsupported object type int).
